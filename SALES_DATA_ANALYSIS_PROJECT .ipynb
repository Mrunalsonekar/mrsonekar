# %% [markdown]
# ####  DATA CLEANING AND IMPORTING DATA

# %%
import pandas as pd

# %%
# Replace 'your_file.xlsx' with the path to your Excel file
file_path = 'sales data.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Now you can work with your DataFrame 'df'
df.head()  # Display the first few rows of the DataFrame
# Out:
#     country  order_value_EUR       cost                 date     category  \
# 0    Sweden         98320.37   77722.25            8/23/2020        Games
# 1    France         46296.26   40319.41            5/15/2020        Games
# 2  Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3    France        203604.46  175344.16            6/26/2019  Electronics
# 4        UK         63979.04   56032.84           10/22/2019        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %%
df.tail()
# Out:
#           country  order_value_EUR       cost                 date  \
# 996        France         69126.50    55902.6  2019-08-12 00:00:00
# 997        France        140943.88  120633.87            5/28/2020
# 998        France        124784.67  106853.11            5/22/2020
# 999       Germany         61968.26   50690.04           12/27/2020
# 1000  Netherlands        172453.10  145688.38            6/24/2020
#
#          category                     customer_name    sales_manager  \
# 996   Electronics     Farrell, Swaniawski and Crist    Othello Bowes
# 997    Appliances                  Armstrong-Little    Othello Bowes
# 998   Electronics  Swaniawski, Runolfsson and Green    Othello Bowes
# 999   Electronics                Romaguera-Dietrich  Rickard Doogood
# 1000     Outdoors                   Kirlin and Sons    Denice Amberg
#
#            sales_rep device_type    order_id
# 996   Avrit Chanders          PC  07-3201531
# 997   Avrit Chanders      Tablet  77-0650807
# ...

# %%
df.shape
# Out:
# (1001, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          1001 non-null   object
#  1   order_value_EUR  996 non-null    float64
#  2   cost             1001 non-null   object
#  3   date             1001 non-null   object
#  4   category         1001 non-null   object
#  5   customer_name    1001 non-null   object
#  6   sales_manager    1001 non-null   object
#  7   sales_rep        1001 non-null   object
#  8   device_type      996 non-null    object
#  9   order_id         1001 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#        order_value_EUR
# count       996.000000
# mean     113193.920361
# std       61599.836849
# min       15100.570000
# 25%       65243.642500
# 50%      105357.645000
# 75%      151047.032500
# max      383996.760000

# %% [markdown]
# ## Filling null values

# %%
df.isnull().sum()
# Out:
# country            0
# order_value_EUR    5
# cost               0
# date               0
# category           0
# customer_name      0
# sales_manager      0
# sales_rep          0
# device_type        5
# order_id           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 10

# %%
df2= df.fillna(value = 0)

# %%
df2
# Out:
#           country  order_value_EUR       cost                 date  \
# 0          Sweden         98320.37   77722.25            8/23/2020
# 1          France         46296.26   40319.41            5/15/2020
# 2        Portugal        140337.34  115708.14  2020-04-09 00:00:00
# 3          France        203604.46  175344.16            6/26/2019
# 4              UK         63979.04   56032.84           10/22/2019
# ...           ...              ...        ...                  ...
# 996        France         69126.50    55902.6  2019-08-12 00:00:00
# 997        France        140943.88  120633.87            5/28/2020
# 998        France        124784.67  106853.11            5/22/2020
# 999       Germany         61968.26   50690.04           12/27/2020
# 1000  Netherlands        172453.10  145688.38            6/24/2020
#
#          category                     customer_name    sales_manager  \
# 0           Games                    Konopelski LLC     Maxie Marrow
# ...

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
# Check for missing values in the entire DataFrame
missing_values = df.isnull().sum()

# To check for missing values in a specific column, you can use:
#missing_values = df['column name'].isnull().sum()

# Print the columns with missing values and their respective counts
print("Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Missing Values:
# order_value_EUR    5
# device_type        5
# dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.impute import SimpleImputer

# %%
df.order_value_EUR
# Out:
# 0        98320.37
# 1        46296.26
# 2       140337.34
# 3       203604.46
# 4        63979.04
#           ...
# 996      69126.50
# 997     140943.88
# 998     124784.67
# 999      61968.26
# 1000    172453.10
# Name: order_value_EUR, Length: 1001, dtype: float64

# %%
#Create a SimpleImputer instance to impute missing values with a strategy (e.g., 'mean', 'median', 'most_frequent')
# Other strategies include 'constant' to replace missing values with a constant value
target_colum = "order_value_EUR"

#fit the simpleimputer on the selected-colum and transform it to capture missing values
imputer = SimpleImputer(strategy='median')
df[target_colum] = imputer.fit_transform(df[[target_colum]])

#now, the specified column in your dataframe contains no missing values.

# %%
df.isnull().sum()
# Out:
# country            0
# order_value_EUR    0
# cost               0
# date               0
# category           0
# customer_name      0
# sales_manager      0
# sales_rep          0
# device_type        5
# order_id           0
# dtype: int64

# %%
df.device_type
# Out:
# 0       Tablet
# 1       Tablet
# 2           PC
# 3       Mobile
# 4           PC
#          ...
# 996         PC
# 997     Tablet
# 998     Tablet
# 999         PC
# 1000        PC
# Name: device_type, Length: 1001, dtype: object

# %%
#Create a SimpleImputer instance to impute missing values with a strategy (e.g., 'mean', 'median', 'most_frequent')
# Other strategies include 'constant' to replace missing values with a constant value
target_colum = "device_type"

#fit the simpleimputer on the selected-colum and transform it to capture missing values
imputer = SimpleImputer(strategy='most_frequent')
df[target_colum] = imputer.fit_transform(df[[target_colum]])

#now, the specified column in your dataframe contains no missing values.

# %%
df.isnull().sum()
# Out:
# country            0
# order_value_EUR    0
# cost               0
# date               0
# category           0
# customer_name      0
# sales_manager      0
# sales_rep          0
# device_type        0
# order_id           0
# dtype: int64

# %% [markdown]
# ### DEALING WITH DATA TYPES OF THE VARIABLES IN A DATA Finding And Dealing With Inconsistant Data

# %%
df.dtypes
# Out:
# country             object
# order_value_EUR    float64
# cost                object
# date                object
# category            object
# customer_name       object
# sales_manager       object
# sales_rep           object
# device_type         object
# order_id            object
# dtype: object

# %%
# Cost comes under numeric data and date is not the object

# %%
# We will deal with cost

# %%
# sample variable containing mixed data 
mixed_data = df['cost']

# Create an empty list to store non-numeric values
non_numeric_values = []

# Iterate through the elements in the variable
for value in mixed_data:
  # Check if the value is a string and not numeric
  if isinstance(value, str) and not value.isnumeric():
    # Add the non-numeric value to the list
    non_numeric_values.append(value)

# Print the non-numeric values
print("Non-Numeric Values:")
print(non_numeric_values)

# This code defines a function that takes a list of mixed data (numeric and non-numeric values) and returns a list of only the non-numeric values. It does this by iterating through the elements in the list and checking if each element is a string that is not numeric. If it is, the element is added to a list of non-numeric values. Finally, the list of non-numeric values is returned.
# Out:
# Non-Numeric Values:
# ['XXX']

# %% [markdown]
# ## Identify And Assign Correct Dataset

# %%
# Create a mask to identify rows with non-numeric values
mask = (df['cost'] == 'XXX')

# Remove the rows that match the mask
df=df[~mask]

# %%
# df['cost'] = pd.to_numeric(df['cost'], errors='coerce')  # Converts invalid values to NaN
# df = df.dropna(subset=['cost'])  # Removes rows with NaN in 'cost'

# %%
### CHECK CODE FOR NON NUMERIC WE NEED TO RE RUN

# %%
# sample variable containing mixed data 
mixed_data = df['cost']

# Create an empty list to store non-numeric values
non_numeric_values = []

# Iterate through the elements in the variable
for value in mixed_data:
  # Check if the value is a string and not numeric
  if isinstance(value, str) and not value.isnumeric():
    # Add the non-numeric value to the list
    non_numeric_values.append(value)

# Print the non-numeric values
print("Non-Numeric Values:")
print(non_numeric_values) #we got output as empty list that there is no non numeric value in the variable cost
# Out:
# Non-Numeric Values:
# []

# %% [markdown]
# ### To assign a correct data type in variable of a dataset

# %%
df['cost'] = df['cost'].astype(float) # our corrected data type is float cost comes in float vales 
# print the data frame with corrected data type
print(df.dtypes)
# Out:
# country             object
# order_value_EUR    float64
# cost               float64
# date                object
# category            object
# customer_name       object
# sales_manager       object
# sales_rep           object
# device_type         object
# order_id            object
# dtype: object

# %%
# for datetime

# %%
df['date'] = df['date'].astype('datetime64')
print(df.dtypes) # data type of our date variable is coverted into datetime 64 in the below output
# Out:
# country                    object
# order_value_EUR           float64
# cost                      float64
# date               datetime64[ns]
# category                   object
# customer_name              object
# sales_manager              object
# sales_rep                  object
# device_type                object
# order_id                   object
# dtype: object

# %%
df.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %% [markdown]
# ### Dealing with duplicate Values

# %% [markdown]
# ### Identified duplicate data first

# %%
# Indentify the duplicated rows on all columns
duplicates =df[df.duplicated()]

#printing the duplicated rows

print("Duplicate Rows:")
duplicates
# Out:
# Duplicate Rows:
#    country  order_value_EUR      cost       date category   customer_name  \
# 23      UK         63979.04  56032.84 2019-10-22    Games  Schoen-Keeling
#
#       sales_manager           sales_rep device_type    order_id
# 23  Jessamine Apark  Genevra Charrisson          PC  27-3437546

# %% [markdown]
# ### Removing duplicates data

# %%
# removing the duplicates rows while keeping the first occurance
df_no_duplicates = df.drop_duplicates()

# print the dataframe Without Duplicates
print("Dataframe Without Duplicates:")
df_no_duplicates
# Out:
# Dataframe Without Duplicates:
#           country  order_value_EUR       cost       date     category  \
# 0          Sweden         98320.37   77722.25 2020-08-23        Games
# 1          France         46296.26   40319.41 2020-05-15        Games
# 2        Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3          France        203604.46  175344.16 2019-06-26  Electronics
# 4              UK         63979.04   56032.84 2019-10-22        Games
# ...           ...              ...        ...        ...          ...
# 996        France         69126.50   55902.60 2019-08-12  Electronics
# 997        France        140943.88  120633.87 2020-05-28   Appliances
# 998        France        124784.67  106853.11 2020-05-22  Electronics
# 999       Germany         61968.26   50690.04 2020-12-27  Electronics
# 1000  Netherlands        172453.10  145688.38 2020-06-24     Outdoors
#
#                          customer_name    sales_manager            sales_rep  \
# ...

# %%
df = pd.read_excel('sales data.xlsx')

# Convert 'date' column to datetime objects, handling different formats
df['date'] = pd.to_datetime(df['date'], errors='coerce')  # Infer format and handle errors

# Format date consistently as YYYY-MM-DD
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# %% [raw]
#  cleaned_data

# %%
cleaned_data = df_no_duplicates

# %%
cleaned_data.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %% [markdown]
# ### STAGE 2. Data Manipulation

# %%
df['cost'] = pd.to_numeric(df['cost'], errors='coerce')  # Convert to float, setting errors to NaN
df_sorted = df.sort_values(by='cost', ascending=True)

# %%
print(df['cost'].apply(type).value_counts())
# Out:
# <class 'float'>    1001
# Name: cost, dtype: int64

# %%
# df_sorted = df.sort_values(by = 'cost' , ascending = True)

# %%
df_sorted
# Out:
#          country  order_value_EUR       cost        date     category  \
# 422       Sweden         15100.57   12113.68  2019-02-20        Games
# 275       France         16388.90   13430.70  2020-03-15  Electronics
# 17        Sweden         15817.05   13743.44  2019-10-03     Clothing
# 971  Netherlands              NaN   14102.75  2020-07-02     Clothing
# 138       Sweden         17524.02   14122.61  2020-12-02        Books
# ..           ...              ...        ...         ...          ...
# 242   Luxembourg        312928.72  270401.71  2019-12-12       Beauty
# 413  Netherlands        353925.06  287528.72  2020-04-12     Clothing
# 84       Ireland        361182.87  288368.40  2019-02-12        Books
# 986           UK        383996.76  304701.43  2019-12-19        Other
# 602     Portugal         57120.58        NaN  2019-11-25        Games
#
#                      customer_name    sales_manager           sales_rep  \
# ...

# %%
 # Filtering out country france

# %%
# filter the dataframe to include the only rows where country is france
France_df = df[df['country'] == 'France']

# %%
France_df
# Out:
#     country  order_value_EUR       cost        date     category  \
# 1    France         46296.26   40319.41  2020-05-15        Games
# 3    France        203604.46  175344.16  2019-06-26  Electronics
# 7    France         96795.99   81395.75  2019-06-21   Appliances
# 16   France         65193.88   53113.45  2019-04-10       Beauty
# 18   France         54079.04   45031.62  2020-05-29        Games
# ..      ...              ...        ...         ...          ...
# 993  France        167072.72  135044.88  2019-10-21     Clothing
# 994  France        157932.84  134148.15  2020-01-31        Games
# 996  France         69126.50   55902.60  2019-08-12  Electronics
# 997  France        140943.88  120633.87  2020-05-28   Appliances
# 998  France        124784.67  106853.11  2020-05-22  Electronics
#
#                         customer_name  sales_manager            sales_rep  \
# 1                          Wisoky Inc  Othello Bowes  Amelina Piscopiello
# ...

# %%
France_Games_df = df[(df['country'] == 'France') & (df['category'] == 'Games')]

# %%
France_Games_df
# Out:
#     country  order_value_EUR       cost        date category  \
# 1    France         46296.26   40319.41  2020-05-15    Games
# 18   France         54079.04   45031.62  2020-05-29    Games
# 50   France        149500.61  125401.11  2020-07-24    Games
# 104  France        146325.53  118333.46  2020-09-08    Games
# 137  France        133754.65  106147.69  2020-09-18    Games
# 236  France        101318.72   86657.90  2019-04-13    Games
# 259  France         18326.41   15067.97  2019-03-02    Games
# 303  France         82697.53   69548.62  2020-12-08    Games
# 310  France         74685.85   59166.13  2020-05-23    Games
# 346  France         99319.33   79127.71  2020-05-26    Games
# 445  France        167935.31  137942.06  2019-04-18    Games
# 559  France         37397.43   30837.92  2020-05-17    Games
# 586  France         68773.03   59082.91  2019-09-30    Games
# 633  France         80839.75   63936.16  2020-05-21    Games
# ...

# %%
Not_france_df = df[df['country'] != 'France']

# %%
Not_france_df
# Out:
#           country  order_value_EUR       cost        date     category  \
# 0          Sweden         98320.37   77722.25  2020-08-23        Games
# 2        Portugal        140337.34  115708.14  2020-04-09   Appliances
# 4              UK         63979.04   56032.84  2019-10-22        Games
# 5           Italy        127075.41  110924.13  2019-09-24     Clothing
# 6          Sweden         69681.43   55529.13  2020-01-25     Clothing
# ...           ...              ...        ...         ...          ...
# 990      Portugal         52209.31   41480.30  2019-03-26       Beauty
# 991      Portugal        125253.59  108269.20  2020-02-17  Smartphones
# 995   Netherlands         95575.75   75504.84  2020-12-23        Books
# 999       Germany         61968.26   50690.04  2020-12-27  Electronics
# 1000  Netherlands        172453.10  145688.38  2020-06-24     Outdoors
#
#                   customer_name    sales_manager           sales_rep  \
# ...

# %% [markdown]
# ## MERGE EXTRA VARIBALES

# %%
# Replace 'your_file.xlsx' with the path to your Excel file
excel_file = 'Extra Variable.xlsx'

# Load the Excel file into a DataFrame
extra_vars = pd.read_excel(excel_file)

# Now you can work with your DataFrame 'df'
extra_vars.head()  # Display the first few rows of the DataFrame
# Out:
#      order_id  refund
# 0  70-0511466   43621
# 1  77-3489084   13385
# 2  65-8218141   69535
# 3  29-5478106   90064
# 4  57-6602854   61736

# %%
merged_df = cleaned_data.merge(extra_vars, on='order_id')

# %%
merged_df
# Out:
#          country  order_value_EUR       cost       date     category  \
# 0         Sweden         98320.37   77722.25 2020-08-23        Games
# 1         France         46296.26   40319.41 2020-05-15        Games
# 2       Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3         France        203604.46  175344.16 2019-06-26  Electronics
# 4             UK         63979.04   56032.84 2019-10-22        Games
# ..           ...              ...        ...        ...          ...
# 994       France         69126.50   55902.60 2019-08-12  Electronics
# 995       France        140943.88  120633.87 2020-05-28   Appliances
# 996       France        124784.67  106853.11 2020-05-22  Electronics
# 997      Germany         61968.26   50690.04 2020-12-27  Electronics
# 998  Netherlands        172453.10  145688.38 2020-06-24     Outdoors
#
#                         customer_name    sales_manager            sales_rep  \
# ...

# %% [markdown]
# ## CONCATE EXTRA DATA (data concatenating)

# %%
# Replace 'your_file.xlsx' with the path to your Excel file
excel_file = 'Extra Data.xlsx'

# Load the Excel file into a DataFrame
extra_data = pd.read_excel(excel_file)

# Now you can work with your DataFrame 'df'
extra_data.head()  # Display the first few rows of the DataFrame
# Out:
#     country  order_value_EUR      cost                 date    category  \
# 0    Sweden         17524.02  14122.61  2020-12-02 00:00:00       Books
# 1    France         64827.80  56043.63            1/20/2019  Appliances
# 2  Portugal         71620.08  62245.01  2019-05-02 00:00:00       Books
# 3  Portugal         74532.02  59752.32  2020-02-04 00:00:00      Beauty
# 4  Portugal         78461.13  63537.82  2020-10-05 00:00:00  Appliances
#
#        customer_name    sales_manager           sales_rep device_type  \
# 0    Goldner-Dibbert     Maxie Marrow       Madelon Bront      Mobile
# 1   Gislason-Stanton    Othello Bowes   Maighdiln Upcraft          PC
# 2     Schoen-Keeling  Celine Tumasian  Smitty Culverhouse         NaN
# 3  Hessel-Stiedemann  Celine Tumasian        Aurelie Wren          PC
# 4  Hessel-Stiedemann  Celine Tumasian  Smitty Culverhouse      Mobile
#
#      order_id  refund
# 0  70-0511466    7964
# 1  62-3312495    4974
# 2  69-6259390    2809
# ...

# %%
# Concatenating DataFrames (stacking vertically)
final_df = pd.concat([merged_df, extra_data], ignore_index=True) # 10 extra rows added i mean concatinated

# %%
final_df
# Out:
#        country  order_value_EUR       cost                 date     category  \
# 0       Sweden         98320.37   77722.25  2020-08-23 00:00:00        Games
# 1       France         46296.26   40319.41  2020-05-15 00:00:00        Games
# 2     Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3       France        203604.46  175344.16  2019-06-26 00:00:00  Electronics
# 4           UK         63979.04   56032.84  2019-10-22 00:00:00        Games
# ...        ...              ...        ...                  ...          ...
# 1004     Spain         84900.24   73701.90            7/14/2020     Clothing
# 1005   Finland        116563.40   92807.78            9/26/2019        Games
# 1006        UK        156585.22  126599.15            8/30/2020  Accessories
# 1007     Spain        178763.42  146621.76           12/22/2019        Games
# 1008  Portugal        296685.56  257480.34  2019-11-07 00:00:00     Clothing
#
# ...

# %% [markdown]
# ### STAGE 3. EXPLORATORY DATA ANALYSIS

# %% [raw]
# Q1.What is the primary country of residence for the majority of our customers?
# Q2.Which product category has the highest frequency of sales?
# Q3.Identify the top 5 customers with the most repeat purchases.
# Q4.Who among the sales managers has achieved the highest number of sales?
# Q5.Who are the top 5 sales representatives with the highest number of sales?
# Q6.Which device is predominantly used for making product purchases?
# Q7.Find the descriptives of order value, cost and refund.

# %% [markdown]
# ### APPLYING FREQUENCY ANALYSIS TO GET SIGNIFICANT INSIGHTS

# %%
 ## Frequency analysis categorical variable is country

# %%
country_frequencies = final_df['country'].value_counts()

# %%
country_frequencies # list of frquency of country
# Out:
# Portugal       242
# France         233
# Sweden         183
# UK             102
# Finland         45
# Ireland         43
# Bulgaria        30
# Spain           28
# Netherlands     28
# Germany         24
# Luxembourg      22
# Denmark         11
# Italy           10
# Belgium          6
# Austria          2
# Name: country, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
country_frequencies.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('The primary country of residence for the majority of our customers')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.xticks(rotation=90) #Rotate x-axis labels if needed
plt.show()

# %%
catproduct_frequencies = final_df['category'].value_counts()
catproduct_frequencies
# Out:
# Clothing       157
# Games          140
# Electronics    134
# Appliances     133
# Books          119
# Beauty         116
# Smartphones     95
# Outdoors        50
# Accessories     36
# Other           29
# Name: category, dtype: int64

# %%
plt.figure(figsize=(10, 7))
catproduct_frequencies.plot(kind='bar', color='orange', edgecolor='black')
plt.title('The product category has the highest frequency of sales')
plt.xlabel('Product Category')
plt.ylabel('Frequency')
plt.xticks(rotation=90) #Rotate x-axis labels if needed
plt.show()

# %%
customer_frequencies = final_df['customer_name'].value_counts()

# %%
customer_frequencies
# Out:
# Johns and Sons                       143
# Hessel-Stiedemann                     57
# Swaniawski, Runolfsson and Green      25
# Dickinson, Hyatt and Berge            24
# Murray, Reichel and Nolan             23
#                                     ...
# Baumbach Group                         2
# Parisian, Steuber and Satterfield      2
# Gorczany-Lehner                        1
# Lind, Mueller and Stoltenberg          1
# Littel-Blick                           1
# Name: customer_name, Length: 75, dtype: int64

# %%
salesman_frequencies = final_df['sales_manager'].value_counts()
salesman_frequencies
# Out:
# Celine Tumasian     242
# Othello Bowes       233
# Maxie Marrow        183
# Jessamine Apark     102
# Hube Corey           45
# Glenine Suttaby      43
# Charil Alpe          30
# Emalia Dinse         28
# Denice Amberg        28
# Rickard Doogood      24
# Ilsa Kob             22
# Modestia Byfford     11
# Piggy Roscrigg       10
# Lambert Norheny       6
# Orsa Geekin           2
# Name: sales_manager, dtype: int64

# %%
salesrep_frequencies = final_df['sales_rep'].value_counts()
salesrep_frequencies
# Out:
# Amelina Piscopiello    56
# Corene Shirer          53
# Aurelie Wren           52
# Hortense Gerring       52
# Ora Grennan            50
# Crysta Halls           47
# Smitty Culverhouse     44
# Avrit Chanders         43
# Brynn Dempster         41
# Madelon Bront          40
# Alyosha Meah           40
# Winny Agnolo           39
# Tarrah Castelletti     38
# Maighdiln Upcraft      37
# Genevra Charrisson     37
# Anita Woakes           36
# Caro Morfield          29
# Nero Harbisher         28
# Jay Morefield          26
# Wat Bowkley            24
# Casie MacBain          24
# Bunnie Tonbridge       23
# Jocelyn Laurentino     22
# Mellicent Mattys       21
# Palm Wetherald         20
# Bernadine Fullagar     15
# Shermy McGready        15
# Perri Aldersley        13
# Joshua Prevost         10
# Bertha Walbrook        10
# Case Desorts            6
# Collin Mackness         6
# Manuel Goudie           5
# Cobby Andersen          5
# Bank Coumbe             2
# ...

# %%
devicetype_frequencies = final_df['device_type'].value_counts()
devicetype_frequencies
# Out:
# PC        789
# Mobile    145
# Tablet     74
# Name: device_type, dtype: int64

# %%
devicetype_frequencies.index
# Out:
# Index(['PC', 'Mobile', 'Tablet'], dtype='object')

# %%
# relative frequencies (percentages)
devicetype_percentages = ( devicetype_frequencies / devicetype_frequencies.sum()) * 100 

# pie chart for the percentages
plt.figure(figsize=(6, 6))
plt.pie(devicetype_percentages, labels=devicetype_percentages.index, autopct='%1.1f%%') # Added formatting for autopct
plt.title('The device is predominantly used for making product purchases')
plt.axis('equal')  # aspect ratio ensures pie is drawn a circle.

# Show pie chart
plt.show()

# %% [markdown]
# ### EDA PART 2

# %% [raw]
# Find the descriptives of order value, cost and refund.
#
# Identify the top 3 product categories based on both order value and cost.
#
# Determine the top 3 customers who contribute the most to profitability and have the highest expenses.
#
# Which sales representative's transactions resulted in the highest amount of refunds to customers?
#
# Who are the consistently loyal customers of your store?
# Under which sales manager, which product category has the highest sales volume?
# In which country did a particular sales representative achieve the highest sales volume?

# %%
# Find descriptives order value, cost and refund.
numeric_columns = ['order_value_EUR', 'cost', 'refund']

# descriptive statistics performed
numeric_summary = final_df[numeric_columns].describe()
numeric_summary
# Out:
#        order_value_EUR           cost        refund
# count      1009.000000    1009.000000   1009.000000
# mean     113267.885208   94422.763518  49236.007929
# std       61615.866535   51693.620772  28744.989463
# min       15100.570000   12113.680000   1009.000000
# 25%       65760.390000   54635.770000  24597.000000
# 50%      105357.645000   86928.030000  48652.000000
# 75%      151012.120000  126080.020000  74664.000000
# max      383996.760000  304701.430000  99539.000000

# %%
import seaborn as sns
# Create a figure with three subplots for the numeric variables
plt.figure(figsize=(12 ,4))

# Plot the distribution of 'order_value_EUR' in the first subplot
plt.subplot(131) # 1 row, 3 columns, first subplot

sns.histplot(final_df['order_value_EUR'], kde=True)
plt.title('Order Value Distribution')

# Plot the distribution of 'cost' in the second subplot
plt.subplot(132) # 1 row, 3 columns, second subplot

sns.histplot(final_df['cost'], kde=True)
plt.title('Cost Distribution')

# Plot the distribution of 'Refund' in the third subplot
plt.subplot(133) # 1 row, 3 columns, third subplot

sns.histplot(final_df['refund'], kde=True)

plt.title('Refund Distribution')

# Adjust layout show the figure
plt.tight_layout()

plt.show()

# %%
# Create a figure with three subplots for the boxplots
plt.figure(figsize=(12, 4))

# Plot the boxplot for 'order_value_EUR' in the first subplot
plt.subplot(131)  # 1 row, 3 columns, first subplot

sns.boxplot(data=final_df['order_value_EUR'])
plt.title('Order Value Boxplot')

# Plot the boxplot for 'Cost' in the second subplot
plt.subplot(132)  # 1 row, 3 columns, second subplot

sns.boxplot(data=final_df['cost'])
plt.title('Cost Boxplot')

# Plot the boxplot for 'Refund' in the third subplot
plt.subplot(133)  # 1 row, 3 columns, third subplot

sns.boxplot(data=final_df['refund'])
plt.title('Refund Boxplot')

# Adjust layout show the figure
plt.tight_layout()

plt.show()

# %% [raw]
# A boxplot is a statistical visualization used to show the distribution, variability, and outliers in a dataset. In this case, the boxplot represents the distribution of the "Cost" variable.
#
# Key Components of the Boxplot:
#
# Box (Interquartile Range - IQR)
#
# The box represents the middle 50% of the data.
# The lower boundary of the box is the first quartile (Q1 or 25th percentile).
# The upper boundary of the box is the third quartile (Q3 or 75th percentile).
# The line inside the box represents the median (50th percentile).

# %% [raw]
# Insights from the Boxplot:-
#
# The median cost is slightly below 100,000.
# The IQR (range between Q1 and Q3) suggests that most cost values lie between 50,000 and 125,000.
# The whiskers extend roughly up to 250,000, beyond which values are considered outliers.
# There are many outliers (dots above the upper whisker), indicating a skewed distribution with some very high-cost values.

# %%
#Identify the top 3 product categories based on both order value and cost.

# Calculate median order value for each product category
median_order_value = final_df.groupby('category')['order_value_EUR'].median()
median_order_value
median_order_value.sort_values(ascending = False)
# Out:
# category
# Accessories    139619.740
# Outdoors       111875.915
# Smartphones    111639.290
# Games          108125.365
# Clothing       103726.570
# Beauty         103345.925
# Appliances     100978.490
# Electronics     99809.630
# Books           99518.860
# Other           77087.840
# Name: order_value_EUR, dtype: float64

# %%
median_cost = final_df.groupby('category')['cost'].median()
median_cost
median_cost.sort_values(ascending = False)
# Out:
# category
# Accessories    116395.415
# Smartphones     96566.370
# Outdoors        94660.390
# Games           92756.590
# Clothing        86581.390
# Beauty          86442.810
# Books           84761.750
# Appliances      84128.530
# Electronics     83245.005
# Other           65894.690
# Name: cost, dtype: float64

# %%
# Determine the top 3 customers who contribute the most to profitability and have the highest expenses.

median_customers = final_df.groupby('customer_name')['order_value_EUR'].median()
median_customers
median_customers.sort_values(ascending = False)
# Out:
# customer_name
# Schuster Inc                     201573.230
# Tromp LLC                        172340.860
# Jacobson, Marvin and Brown       158011.300
# O'Connell-Mitchell               156441.185
# West-Cummings                    153823.740
#                                     ...
# Rath-Schroeder                    69664.885
# Homenick-Marvin                   57748.435
# Lind, Mueller and Stoltenberg     57115.990
# Lueilwitz, Kerluke and Lesch      54079.040
# Gorczany-Lehner                   33724.530
# Name: order_value_EUR, Length: 75, dtype: float64

# %%
median_customers_cost = final_df.groupby('customer_name')['cost'].median()
median_customers_cost
median_customers_cost.sort_values(ascending = False)
# Out:
# customer_name
# Schuster Inc                     163052.820
# Jacobson, Marvin and Brown       137390.830
# Tromp LLC                        136562.900
# West-Cummings                    129258.090
# O'Connell-Mitchell               129090.565
#                                     ...
# Rath-Schroeder                    56826.990
# Lind, Mueller and Stoltenberg     48976.960
# Homenick-Marvin                   46504.600
# Lueilwitz, Kerluke and Lesch      45031.620
# Gorczany-Lehner                   26770.530
# Name: cost, Length: 75, dtype: float64

# %%
# Which sales representative's transactions resulted in the highest amount of refunds to customers?
median_sales_rep = final_df.groupby('sales_rep')['refund'].median()
median_sales_rep
median_sales_rep.sort_values(ascending = False)
# Out:
# sales_rep
# Mellicent Mattys       65788.0
# Corene Shirer          65117.0
# Jay Morefield          63302.5
# Winny Agnolo           60180.0
# Bernadine Fullagar     59556.0
# Palm Wetherald         55253.5
# Jocelyn Laurentino     54422.5
# Hortense Gerring       54201.5
# Joshua Prevost         53876.5
# Amelina Piscopiello    51615.5
# Madelon Bront          50451.5
# Collin Mackness        49281.5
# Anita Woakes           48598.0
# Brynn Dempster         48333.0
# Wat Bowkley            48265.0
# Shermy McGready        48238.0
# Nero Harbisher         47320.5
# Maighdiln Upcraft      46850.0
# Genevra Charrisson     46381.0
# Bertha Walbrook        46047.5
# Aurelie Wren           46036.0
# Avrit Chanders         45035.0
# Tarrah Castelletti     43647.5
# Bank Coumbe            42433.0
# Alyosha Meah           41807.5
# Ora Grennan            40519.0
# Casie MacBain          40373.5
# Crysta Halls           39735.0
# Smitty Culverhouse     39691.5
# ...

# %%
# Who are the consistently loyal customers of your store?

# Create pivot table
pivot_table = df.pivot_table(
    index='customer_name', 
    values=['order_value_EUR', 'cost'], 
    aggfunc={'order_value_EUR': 'median', 'cost': 'median', 'customer_name': 'count'}
)

pivot_table = pivot_table.rename(columns={'order_value_EUR': 'Median_Sales',
                                           'cost': 'Median_Cost',
                                           'customer_name': 'Count'})
# Display the pivot table
pivot_table
sorted_pivot_table = pivot_table.sort_values(by = 'Count', ascending = False)
sorted_pivot_table
top_10 = sorted_pivot_table[0:10]
top_10
# Out:
#                                   Median_Cost  Count  Median_Sales
# customer_name
# Johns and Sons                      86679.665    142    106115.850
# Hessel-Stiedemann                   80342.700     55     97141.875
# Swaniawski, Runolfsson and Green    84690.350     25     97105.480
# Dickinson, Hyatt and Berge          85886.100     24    104540.680
# Murray, Reichel and Nolan           71501.100     23     88832.280
# Kihn Inc                            66742.150     22     80450.080
# Rowe, Hermiston and Kessler         66065.680     22     77690.890
# Larkin-Collier                     101516.450     21    126974.920
# Tillman and Sons                    75839.400     21     91350.760
# Wisoky Inc                          94336.180     21    115226.800

# %%
# Create a figure with two subplots
fig, ax1 = plt.subplots(figsize=(30, 10)) # Adjust figure size as needed

# Plot the count in a line plot
sns.lineplot(data = top_10['Count'], marker='o', ax=ax1, color='tab:blue') # Added marker

ax1.set_xlabel('Customers Name')
ax1.set_ylabel('Count', color="tab:blue")
ax1.tick_params(axis='y', labelcolor="tab:blue")

# Create a second y-axis for the bar plots
ax2 = ax1.twinx()

# Plot the median sales and median cost in bar plots
top_10[['Median_Sales', 'Median_Cost']].plot(kind='bar', ax=ax2, width=0.4, position=0) # Adjust width and position as needed

ax2.set_ylabel('Values', color="black")
ax2.tick_params(axis='y', labelcolor="black")

# Customize the plot
plt.title('Median Sales, Cost, and Product Purchased by Customers')

ax2.legend(loc='upper left', labels=['Median Sales', 'Median Cost']) # Corrected legend labels

# Show the plot
plt.show()

# %%
# Under which sales manager, which product category has the highest sales volume?

# Create a crosstabulation of Category1 and Category2
crosstab = pd.crosstab(final_df['sales_manager'], df['category'])
crosstab
# Out:
# category          Accessories  Appliances  Beauty  Books  Clothing  \
# sales_manager
# Celine Tumasian             5          30      26     18        42
# Charil Alpe                 1           5       3      2         3
# Denice Amberg               0           1       4      1         6
# Emalia Dinse                1           6       3      5         3
# Glenine Suttaby             4           3       2      6         8
# Hube Corey                  0           4       9      6         6
# Ilsa Kob                    0           2       3      7         3
# Jessamine Apark             4          14      11     13        19
# Lambert Norheny             0           3       0      0         0
# Maxie Marrow               11          22      21     18        29
# Modestia Byfford            1           1       0      2         2
# Orsa Geekin                 0           0       0      0         0
# Othello Bowes               5          35      31     35        28
# ...

# %%
# Visualize the crosstabulation as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d', cbar=True)
plt.title('Crosstabulation Heatmap')
plt.xlabel('Product Category')
plt.ylabel('Sales Managers')

# Show the plot
plt.show()

# %%
crosstab_sales_rep = pd.crosstab(final_df['sales_rep'], df['country'])
crosstab_sales_rep
# Out:
# country              Austria  Belgium  Bulgaria  Denmark  Finland  France  \
# sales_rep
# Alyosha Meah               0        0         0        0        4      10
# Amelina Piscopiello        0        0         1        1        0      11
# Anita Woakes               0        1         1        0        4       6
# Aurelie Wren               0        0         2        0        5      10
# Avrit Chanders             0        0         3        1        0      10
# Bank Coumbe                0        0         0        0        0       0
# Bernadine Fullagar         0        0         1        0        2       3
# Bertha Walbrook            0        0         1        0        0       2
# Brynn Dempster             0        0         1        0        3       4
# Bunnie Tonbridge           0        1         1        1        2       5
# Caro Morfield              0        0         1        0        1       9
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(crosstab_sales_rep, annot=True, cmap="YlGnBu", fmt='d', cbar=True)
plt.title('Crosstabulation Heatmap')
plt.xlabel('Country')
plt.ylabel('Sales Representatives')

# Show the plot
plt.show()

# %%
# In which country did a particular sales representative achieve the highest sales volume?

# Find the relationship between order value, cost and refund amount.

# Calculate the correlation matrix
correlation_matrix = final_df[['order_value_EUR', 'cost', 'refund']].corr()

# Visualize the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
#  ### DETECTING NORMALITY

# %%
# Create subplots for the KDE plots
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the first KDE plot
sns.kdeplot(final_df['order_value_EUR'], label="Order values", shade=True)

# Plot the second KDE plot
sns.kdeplot(final_df['cost'], label="Cost", shade=True)

# Plot the third KDE plot
sns.kdeplot(final_df['refund'], label="Refund", shade=True)

# Set plot title and labels
plt.title('KDE Plots for Three Numeric Variables')
plt.xlabel('Value')
plt.ylabel('Density')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\4134956426.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(final_df['order_value_EUR'], label="Order values", shade=True)
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\4134956426.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(final_df['cost'], label="Cost", shade=True)
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\4134956426.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(final_df['refund'], label="Refund", shade=True)

# %% [markdown]
# ### Square root method

# %%
#Square root
import numpy as np

# Apply the square root transformation
sqrt_orderval = np.sqrt(final_df['order_value_EUR'])

sns.kdeplot(sqrt_orderval, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\3513665119.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sqrt_orderval, shade=True)
# <Axes: xlabel='order_value_EUR', ylabel='Density'>

# %%
sqrt_cost = np.sqrt(final_df['cost'])
sns.kdeplot(sqrt_cost, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\3213445499.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sqrt_cost, shade=True)
# <Axes: xlabel='cost', ylabel='Density'>

# %%
sqrt_refund = np.sqrt(final_df['refund'])
sns.kdeplot(sqrt_refund, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\64812349.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sqrt_refund, shade=True)
# <Axes: xlabel='refund', ylabel='Density'>

# %% [markdown]
# ## LOG METHOD

# %%
#Logarithmic

# Apply the log transformation
log_orderval = np.log(final_df['order_value_EUR'])

sns.kdeplot(log_orderval, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\1348072881.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(log_orderval, shade=True)
# <Axes: xlabel='order_value_EUR', ylabel='Density'>

# %%
log_cost = np.log(final_df['cost'])
sns.kdeplot(log_cost, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\3305276107.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(log_cost, shade=True)
# <Axes: xlabel='cost', ylabel='Density'>

# %% [markdown]
# ## BOX COX METHOD

# %%
#Box - cox
from scipy import stats

# Apply the Box-Cox transformation
boxcox_orderval, lambda_value = stats.boxcox(final_df['order_value_EUR'])
sns.kdeplot(boxcox_orderval, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\3470634455.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(boxcox_orderval, shade=True)
# <Axes: ylabel='Density'>

# %%
boxcox_cost, lambda_value = stats.boxcox(final_df['cost'])
sns.kdeplot(boxcox_cost, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\2582371686.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(boxcox_cost, shade=True)
# <Axes: ylabel='Density'>

# %%
boxcox_refund, lambda_value = stats.boxcox(final_df['refund'])
sns.kdeplot(boxcox_refund, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\472440282.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(boxcox_refund, shade=True)
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Yeo-johnson method

# %%
#Yeo - Johnson

# Apply the Yeo-Johnson transformation
yeo_orderval, lambda_value = stats.yeojohnson(final_df['order_value_EUR'])
sns.kdeplot(yeo_orderval, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\1931257245.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(yeo_orderval, shade=True)
# <Axes: ylabel='Density'>

# %%
yeo_cost, lambda_value = stats.yeojohnson(final_df['cost'])
sns.kdeplot(yeo_cost, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\3789555174.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(yeo_cost, shade=True)
# <Axes: ylabel='Density'>

# %%
yeo_refund, lambda_value = stats.yeojohnson(final_df['refund'])
sns.kdeplot(yeo_refund, shade=True)
# Out:
# C:\Users\Mrunal\AppData\Local\Temp\ipykernel_1548\754364602.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(yeo_refund, shade=True)
# <Axes: ylabel='Density'>

# %% [markdown]
# # One way ANOVA

# %%
final_df['yeo_cost'] = yeo_cost

# Create sample data for three or more groups (replace this with your actual data)
PC_data = final_df[final_df['device_type'] == 'PC']
Tab_data = final_df[final_df['device_type'] == 'Tablet']
Mob_data = final_df[final_df['device_type'] == 'Mobile']

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(PC_data['yeo_cost'], Tab_data['yeo_cost'], Mob_data['yeo_cost'])

# Print the results
print("One-way ANOVA F-statistic:", f_statistic)
print("P-value:", p_value)

# Determine if the results are statistically significant
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference among the groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference among the groups.")
# Out:
# One-way ANOVA F-statistic: 1.137886450846143
# P-value: 0.3209082415386059
# Fail to reject the null hypothesis: There is no significant difference among the groups.

# %%
# Perform Pearson correlation tests
correlation1, p_value1 = stats.pearsonr(boxcox_orderval, yeo_cost)
correlation2, p_value2 = stats.pearsonr(boxcox_orderval, final_df['refund'])
correlation3, p_value3 = stats.pearsonr(final_df['refund'], yeo_cost)

# Print the correlation coefficients and p-values
print("Correlation between order value and cost:", correlation1)
print("P-value:", p_value1)
print("Correlation between order value and refund:", correlation2)
print("P-value:", p_value2)
print("Correlation between cost and refund:", correlation3)
print("P-value:", p_value3)

# Determine if the correlations are statistically significant
alpha = 0.05  # Significance level
if p_value1 < alpha:
    print("Correlation between order value and cost is statistically significant.")
else:
    print("Correlation between  order value and cost is not statistically significant.")

if p_value2 < alpha:
    print("Correlation between order value and refund is statistically significant.")
else:
    print("Correlation between order value and refund is not statistically significant.")

if p_value3 < alpha:
    print("Correlation between cost and refund is statistically significant.")
else:
    print("Correlation between cost and refund is not statistically significant.")
# Out:
# Correlation between order value and cost: 0.992254154750269
# P-value: 0.0
# Correlation between order value and refund: 0.9597956424157416
# P-value: 0.0
# Correlation between cost and refund: 0.9535863737925905
# P-value: 0.0
# Correlation between order value and cost is statistically significant.
# Correlation between order value and refund is statistically significant.
# Correlation between cost and refund is statistically significant.

# %% [markdown]
# ## Multiple Regression

# %%
import statsmodels.api as sm

# Add a constant term to the independent variables
X = sm.add_constant(np.column_stack((boxcox_orderval, yeo_cost)))

# Fit the linear regression model
model = sm.OLS(final_df['refund'], X).fit()

# Get the regression coefficients
coefficients = model.params

# Print the regression results
print("Regression Coefficients:")
print("Intercept:", coefficients[0])
print("Order Value Coefficient:", coefficients[1])
print("Cost Coefficient:", coefficients[2])

# Print the summary of the regression model
print("\nRegression Summary:")
print(model.summary())
# Out:
# Regression Coefficients:
# Intercept: -97940.21945436351
# Order Value Coefficient: 1099.3033949423245
# Cost Coefficient: 107.14394214833801
#
# Regression Summary:
#                             OLS Regression Results
# ...
# Dep. Variable:                 refund   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                     5889.
# Date:                Sat, 01 Feb 2025   Prob (F-statistic):               0.00
# Time:                        01:38:24   Log-Likelihood:                -10507.
# No. Observations:                1009   AIC:                         2.102e+04
# Df Residuals:                    1006   BIC:                         2.104e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...
